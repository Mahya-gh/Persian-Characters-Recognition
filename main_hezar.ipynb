# %% [markdown]
# <a href="https://colab.research.google.com/github/Mahya-gh/Persian-Characters-Recognition/blob/main/main_hezar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
pip install hezar

# %%
# !pip install hezar[all]  # For a full installation
# !pip install hezar[nlp]   # For NLP
# !pip install hezar[vision]   # For computer vision models
# !pip install hezar[audio] # For audio and speech
# !pip install hezar[embeddings]   # For word embedding models

# %%
# !git clone https://github.com/hezarai/hezar.git
# !pip install ./hezar
# Out:
# fatal: destination path 'hezar' already exists and is not an empty directory.
# Processing ./hezar
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for hezar: filename=hezar-0.40.3-py3-none-any.whl size=190726 sha256=1b54a545678337cb894cdfd149c30b548baec06a69fbe7701276eb1ec5743f04
#   Stored in directory: /tmp/pip-ephem-wheel-cache-htjuvrto/wheels/96/47/01/3860c0b46ee8b2ca9bd9c725005e399da2a5c36875bb3c0d20
# Successfully built hezar
# ...
#   Attempting uninstall: hezar
#     Found existing installation: hezar 0.40.3
#     Uninstalling hezar-0.40.3:
#       Successfully uninstalled hezar-0.40.3
# ...

# %%
from hezar.models import Model
import cv2
import matplotlib.pyplot as plt
model = Model.load("hezarai/crnn-fa-license-plate-recognition")
plate_text = model.predict("/content/drive/MyDrive/plate2.jpg")
plt.imshow(cv2.imread("/content/drive/MyDrive/plate2.jpg"))
print(plate_text)  # Persian text of mixed numbers and characters might not show correctly in the console
# Out:
# /usr/local/lib/python3.10/dist-packages/hezar/models/model.py:161: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...
